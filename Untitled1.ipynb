# %% [markdown]
# <a href="https://colab.research.google.com/github/NishaBhardwaj2004/Cancer-prediction/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import cv2

import PIL.Image as Image
import os

import matplotlib.pyplot as plt

import tensorflow as tf
import tensorflow_hub as hub

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
IMAGE_SHAPE=(128,128)
classifier=tf.keras.Sequential([hub.KerasLayer("https://tfhub.dev/google/imagenet/mobilenet_v2_035_128/classification/2",input_shape=IMAGE_SHAPE+(3,))])

# %%
IMAGE_SHAPE+(3,)
# Out:
# (128, 128, 3)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e1c1cf6e-4cf9-46d6-8406-4fb460513d12" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e1c1cf6e-4cf9-46d6-8406-4fb460513d12">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gold_fish=Image.open('goldfish.jpg').resize(IMAGE_SHAPE)
gold_fish
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
gold_fish=np.array(gold_fish)/255
gold_fish.shape
# Out:
# (128, 128, 3)

# %%
gold_fish[np.newaxis, ...].shape
# Out:
# (1, 128, 128, 3)

# %%
result=classifier.predict(gold_fish[np.newaxis, ...])
result.shape
# Out:
# 1/1 [==============================] - 0s 28ms/step
# (1, 1001)

# %%
predicted_label_index=np.argmax(result)
predicted_label_index
# Out:
# 2

# %%
result
# Out:
# array([[ 0.5140054 ,  2.8574958 , 12.258903  , ...,  1.9390174 ,
#         -0.45755064,  0.0312461 ]], dtype=float32)

# %%
image_labels = []
with open("ImageNetLabels.txt", "r") as f:
    image_labels = f.read().splitlines()
image_labels[:5]
# Out:
# ['background', 'tench', 'goldfish', 'great white shark', 'tiger shark']

# %%
image_labels[2]
# Out:
# 'goldfish'

# %%
# prompt: get a flower dataset from tensorflow hub in dataset_url

import pathlib
dataset_url = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"
archive = tf.keras.utils.get_file(origin=dataset_url, extract=True)
data_dir = pathlib.Path(archive).with_suffix('')
# Out:
# ...
# 228813984/228813984 [==============================] - 1s 0us/step

# %%
data_dir
# Out:
# PosixPath('/root/.keras/datasets/flower_photos')

# %%
list(data_dir.glob('*/*.jpg'))[:5]
# Out:
# [PosixPath('/root/.keras/datasets/flower_photos/tulips/12557176134_ecbf15885b.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/tulips/8713397694_bcbcbba2c2_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/tulips/5631861819_f0eb39a357_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/tulips/12949131454_4d3392f4dd_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/tulips/14027372499_30f934d24f_m.jpg')]

# %%
image_count=len(list(data_dir.glob('*/*.jpg')))
image_count
# Out:
# 3670

# %%
roses=list(data_dir.glob('roses/*'))
roses[:5]
# Out:
# [PosixPath('/root/.keras/datasets/flower_photos/roses/5231103167_a03280e9f6_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/9216321995_83df405ea9.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/8125886145_ae99f91fd0.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/5487945052_bcb8e9fc8b_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/3500121696_5b6a69effb_n.jpg')]

# %%
Image.open(str(roses[6]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x329>

# %%
tulips=list(data_dir.glob('tulips/*'))
tulips[:5]
# Out:
# [PosixPath('/root/.keras/datasets/flower_photos/tulips/12557176134_ecbf15885b.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/tulips/8713397694_bcbcbba2c2_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/tulips/5631861819_f0eb39a357_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/tulips/12949131454_4d3392f4dd_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/tulips/14027372499_30f934d24f_m.jpg')]

# %%
Image.open(str(tulips[5]))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x314>

# %%
flowers_images_dict={
    'roses':list(data_dir.glob('roses/*')),
    'daisy':list(data_dir.glob('daisy/*')),
    'dandelion':list(data_dir.glob('dandelion/*')),
    'sunflowers':list(data_dir.glob('sunflowers/*')),
    'tulips':list(data_dir.glob('tulips/*')),



}

# %%
flowers_images_dict['roses']
# Out:
# [PosixPath('/root/.keras/datasets/flower_photos/roses/5231103167_a03280e9f6_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/9216321995_83df405ea9.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/8125886145_ae99f91fd0.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/5487945052_bcb8e9fc8b_m.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/3500121696_5b6a69effb_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/8692040971_826614516f_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/3422228549_f147d6e642.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/2331651885_619653a5d3.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/5419629292_2f06e4b295.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/6867597533_d65d1c39fb_n.jpg'),
#  PosixPath('/root/.keras/datasets/flower_photos/roses/4292443009_3a2831b0b9_m.jpg'),
# ...

# %%
img=cv2.imread(str(flowers_images_dict['roses'][0]))

# %%
img.shape
# Out:
# (240, 320, 3)

# %%
img
# Out:
# array([[[28, 37, 46],
#         [28, 38, 45],
#         [26, 38, 40],
#         ...,
#         [40, 38, 37],
#         [41, 39, 38],
#         [42, 40, 39]],
#
#        [[29, 38, 47],
#         [28, 38, 45],
#         [25, 36, 40],
#         ...,
#         [41, 39, 38],
#         [41, 39, 38],
#         [42, 40, 39]],
#
#        [[28, 37, 46],
#         [26, 35, 44],
#         [23, 33, 40],
#         ...,
#         [41, 39, 38],
#         [41, 39, 38],
#         [42, 40, 39]],
#
#        ...,
#
#        [[26, 42, 58],
#         [19, 35, 47],
#         [19, 35, 41],
#         ...,
#         [19, 29, 39],
#         [48, 61, 63],
#         [47, 58, 55]],
#
#        [[34, 46, 56],
#         [25, 41, 48],
#         [22, 40, 47],
#         ...,
#         [27, 41, 53],
#         [48, 61, 63],
#         [50, 62, 56]],
#
#        [[36, 46, 53],
#         [25, 41, 48],
#         [22, 43, 51],
#         ...,
#         [32, 48, 60],
#         [42, 57, 59],
#         [54, 66, 60]]], dtype=uint8)

# %%
cv2.resize(img,IMAGE_SHAPE).shape
# Out:
# (128, 128, 3)

# %%
FLOWERS_LABELS_DICT={
    'roses':0,
    'daisy':1,
    'dandelion':2,
    "sunflowers":3,
    'tulips':4
}

# %%
X,y=[],[]

for flower_name, images in flowers_images_dict.items():
  for image in images:
    i=cv2.imread(str(image))
    resized_img=cv2.resize(i,IMAGE_SHAPE)
    X.append(resized_img)
    y.append(FLOWERS_LABELS_DICT[flower_name])

# %%
# prompt: correct the above code to give an array in x containning matrix of all images in flowers_ima
# ges_dict for each flower

X, y = [], []

for flower_name, images in flowers_images_dict.items():
  for image in images:
    img = cv2.imread(str(image))
    resized_img = cv2.resize(img, IMAGE_SHAPE)
    X.append(resized_img)
    y.append(FLOWERS_LABELS_DICT[flower_name])

X = np.array(X)

# %%
X[0]/255
# Out:
# array([[[0.10980392, 0.14901961, 0.17647059],
#         [0.08627451, 0.1254902 , 0.1254902 ],
#         [0.06666667, 0.07843137, 0.07843137],
#         ...,
#         [0.1372549 , 0.14117647, 0.13333333],
#         [0.15294118, 0.14509804, 0.14117647],
#         [0.16078431, 0.15294118, 0.14901961]],
#
#        [[0.09803922, 0.13333333, 0.17254902],
#         [0.07843137, 0.11372549, 0.12941176],
#         [0.0627451 , 0.0745098 , 0.07843137],
#         ...,
#         [0.1372549 , 0.14117647, 0.13333333],
#         [0.15686275, 0.14901961, 0.14509804],
#         [0.16470588, 0.15294118, 0.14901961]],
#
#        [[0.08627451, 0.12941176, 0.15686275],
#         [0.07058824, 0.10980392, 0.13333333],
#         [0.05882353, 0.0745098 , 0.08235294],
#         ...,
#         [0.14509804, 0.1372549 , 0.13333333],
#         [0.15686275, 0.14901961, 0.14509804],
#         [0.17254902, 0.15686275, 0.15294118]],
#
#        ...,
#
#        [[0.02745098, 0.12941176, 0.19215686],
# ...

# %%
y=np.array(y)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=0)

# %%
X_train_scaled=X_train/255
X_test_scaled=X_test/255

# %%
gold_fish=np.array(gold_fish)/255.0
gold_fish.shape
# Out:
# (128, 128, 3)

# %%
X_train_scaled[0]
# Out:
# array([[[0.        , 0.04705882, 0.0627451 ],
#         [0.00392157, 0.04313725, 0.05882353],
#         [0.00392157, 0.04313725, 0.05882353],
#         ...,
#         [0.02745098, 0.24705882, 0.32156863],
#         [0.03137255, 0.26666667, 0.34509804],
#         [0.04313725, 0.2745098 , 0.35294118]],
#
#        [[0.00392157, 0.05098039, 0.06666667],
#         [0.00392157, 0.05490196, 0.06666667],
#         [0.00392157, 0.05882353, 0.08235294],
#         ...,
#         [0.02352941, 0.23529412, 0.31372549],
#         [0.02352941, 0.25098039, 0.32941176],
#         [0.03137255, 0.2627451 , 0.34117647]],
#
#        [[0.00784314, 0.08235294, 0.10196078],
#         [0.00392157, 0.07843137, 0.09803922],
#         [0.00392157, 0.07843137, 0.09803922],
#         ...,
#         [0.02745098, 0.22745098, 0.30588235],
#         [0.01960784, 0.24313725, 0.31764706],
#         [0.02745098, 0.25098039, 0.33333333]],
#
#        ...,
#
#        [[0.00392157, 0.19607843, 0.20392157],
# ...

# %%
plt.axis('off')
plt.matshow(X[0])

# %%
plt.axis('off')
plt.imshow(X[1])

# %%
plt.axis('off')
plt.imshow(X[2])

# %%
predicted=classifier.predict(np.array([X[0],X[1],X[2]]))
predicted=np.argmax(predicted,axis=1)
predicted
# Out:
# 1/1 [==============================] - 0s 34ms/step
# array([905, 905, 905])

# %%
image_labels[905]
# Out:
# 'window screen'

# %%
feature_extractor_model="https://tfhub.dev/google/imagenet/mobilenet_v2_035_128/feature_vector/2"

# %%
pretrained_model_without_top_layer=hub.KerasLayer(
    feature_extractor_model,input_shape=(128,128,3),trainable=False
)

# %%
num_of_flowers=5

model=tf.keras.Sequential([
    pretrained_model_without_top_layer,
    tf.keras.layers.Dense(num_of_flowers)
])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  keras_layer_1 (KerasLayer)  (None, 1280)              410208
#
#  dense (Dense)               (None, 5)                 6405
#
# ...
# Total params: 416613 (1.59 MB)
# Trainable params: 6405 (25.02 KB)
# Non-trainable params: 410208 (1.56 MB)
# _________________________________________________________________

# %%
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['acc']
)

model.fit(X_train_scaled,y_train,epochs=5)
# Out:
# Epoch 1/5
# 86/86 [==============================] - 13s 120ms/step - loss: 0.9192 - acc: 0.6544
# Epoch 2/5
# 86/86 [==============================] - 10s 115ms/step - loss: 0.5466 - acc: 0.8041
# Epoch 3/5
# 86/86 [==============================] - 9s 103ms/step - loss: 0.4527 - acc: 0.8408
# Epoch 4/5
# 86/86 [==============================] - 12s 139ms/step - loss: 0.3863 - acc: 0.8735
# Epoch 5/5
# 86/86 [==============================] - 10s 119ms/step - loss: 0.3420 - acc: 0.8899

# %%
model.evaluate(X_test_scaled,y_test)
# Out:
# 29/29 [==============================] - 6s 181ms/step - loss: 0.5362 - acc: 0.8072
# [0.5362321734428406, 0.8071895241737366]

# %%
pred=model.predict(np.array([X[0],X[1],X[2]]))
pred
# Out:
# 1/1 [==============================] - 1s 1s/step
# array([[-4.807169  , -0.79207885,  1.2341096 , -0.80125415,  1.7908239 ],
#        [-2.7644875 , -1.1261288 , -1.0418661 , -3.0222886 ,  2.4777384 ],
#        [-0.9136084 , -1.9906894 , -2.1711018 , -1.5933465 ,  1.5960283 ]],
#       dtype=float32)

# %%
pred=np.argmax(pred,axis=1)

# %%
pred
# Out:
# array([4, 4, 4])

# %%
image_labels[4]
# Out:
# 'tiger shark'
